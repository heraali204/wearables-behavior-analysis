# %%
# !pip install duckdb
# Out:
# Requirement already satisfied: duckdb in /opt/anaconda3/lib/python3.13/site-packages (1.4.3)

# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### User devices
# - No time series metrics
# - not for modeling, can be used later to explain coverage

# %%
devices_registry = pd.read_csv("wearables_synthetic_raw/devices_registry.csv")

# %%
devices_registry.head()
# Out:
#           user_id   vendor                  model   device_id   paired_at  \
# 0  U_XAJI0Y6DPBHS     Oura         Oura Ring Gen3  D_6WIXAW63  2024-02-19
# 1  U_5NQ4FMYZYCWT   Fitbit         Fitbit Versa 4  D_3DR2H2P3  2025-01-12
# 2  U_W2PCN9T84AZY   Fitbit         Fitbit Versa 4  D_UE421VME  2024-03-13
# 3  U_W2PCN9T84AZY  Samsung  Samsung Galaxy Watch6  D_ZTP7BD4W  2025-02-02
# 4  U_1ERTJ5PHT0HL   Fitbit         Fitbit Versa 4  D_A7ZVKY2R  2024-03-05
#
#   firmware active_flag
# 0      3.4        TRUE
# 1      NaN           0
# 2      3.4           1
# 3    2.1.0           1
# 4    2.1.0           1

# %%
devices_registry.describe()
# Out:
#                user_id vendor           model   device_id   paired_at  \
# count              221    221             221         221         221
# unique             120      5               8         221         169
# top     U_XEK47O3LQI7E  Apple  Oura Ring Gen3  D_6WIXAW63  2024-08-05
# freq                 3     55              33           1           3
#
#        firmware active_flag
# count       185         190
# unique        5           4
# top       2.1.0           1
# freq         48          95

# %%
devices_registry.shape
# Out:
# (221, 7)

# %%
devices_registry.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      221 non-null    object
#  1   vendor       221 non-null    object
#  2   model        221 non-null    object
#  3   device_id    221 non-null    object
#  4   paired_at    221 non-null    object
#  5   firmware     185 non-null    object
#  6   active_flag  190 non-null    object
# dtypes: object(7)
# memory usage: 12.2+ KB

# %% [markdown]
# ### Users
# - clean but sex is inconsistent
# - baseline weight has no unit and inconsistent
# - home_tz is present but users may travel
# - not ground truth

# %%
users = pd.read_csv("wearables_synthetic_raw/users.csv")

# %%
users.head()
# Out:
#           user_id                        email_hash  age      sex  height_cm  \
# 0  U_XAJI0Y6DPBHS  5501e76c0ed6b0ffea1b8be48fdb4697   34  Unknown        165
# 1  U_5NQ4FMYZYCWT  0942476dafed98f4081ed2e380d92bab   43        M        164
# 2  U_W2PCN9T84AZY  b0198e2c87e43c6262afa887ea89b1b6   43   female        173
# 3  U_1ERTJ5PHT0HL  12bdf3ddb4d87bd4dc83166db001549b   35      NaN        162
# 4  U_OM5IGQPKI7P5  42ab6d0178ca086e55641dda5afa182a   32        F        149
#
#    baseline_weight              home_tz
# 0             91.7        Europe/Berlin
# 1             75.8           Asia/Tokyo
# 2             71.5         Asia/Karachi
# 3             71.6         Asia/Karachi
# 4             49.0  America/Los_Angeles

# %%
users.describe()
# Out:
#               age   height_cm  baseline_weight
# count  120.000000  120.000000       120.000000
# mean    31.208333  164.833333        82.027500
# std      6.393137    8.283154        18.788558
# min     18.000000  145.000000        45.000000
# 25%     27.000000  159.000000        68.175000
# 50%     32.000000  164.000000        82.250000
# 75%     35.000000  171.250000        93.550000
# max     48.000000  187.000000       145.000000

# %%
users.shape
# Out:
# (120, 7)

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   user_id          120 non-null    object
#  1   email_hash       120 non-null    object
#  2   age              120 non-null    int64
#  3   sex              99 non-null     object
#  4   height_cm        120 non-null    int64
#  5   baseline_weight  120 non-null    float64
#  6   home_tz          120 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 6.7+ KB

# %% [markdown]
# ### Apple Health
# - event-based, not daily
# - everything is in one column (value)
# - meaning depends on type column
# - units differ
# - sleep is not a number
# - multiple rows per user per day

# %%
apple_health = pd.read_csv("wearables_synthetic_raw/apple_health_export_like.csv")

# %%
apple_health.head()
# Out:
#              user                                      type  \
# 0  U_OM5IGQPKI7P5     HKCategoryTypeIdentifierSleepAnalysis
# 1  U_OM5IGQPKI7P5         HKQuantityTypeIdentifierStepCount
# 2  U_OM5IGQPKI7P5     HKCategoryTypeIdentifierSleepAnalysis
# 3  U_OM5IGQPKI7P5  HKQuantityTypeIdentifierRestingHeartRate
# 4  U_OM5IGQPKI7P5         HKQuantityTypeIdentifierStepCount
#
#               startDate              endDate    value   unit   sourceName  \
# 0   2024-01-01T00:00:00  2024-01-02T00:00:00  13242.0    min          NaN
# 1   2024-01-02T00:00:00  2024-01-03T00:00:00     48.3  count       Health
# 2   2024-01-03T00:00:00  2024-01-04T00:00:00  10489.0    min       iPhone
# 3   2024-01-04T00:00:00  2024-01-05T00:00:00  11030.0    bpm       Health
# 4  2024-01-05 00:00:00   2024-01-06T00:00:00   2243.6  count  Apple Watch
#
#                  device                 metadata
# 0  Apple Watch Series 8  {alg:v2,confidence:0.8}
# 1     Apple Watch Ultra  {alg:v2,confidence:0.8}
# 2     Apple Watch Ultra            {workout:run}
# 3  Apple Watch Series 8  {alg:v2,confidence:0.8}
# 4  Apple Watch Series 8  {alg:v2,confidence:0.8}

# %%
apple_health.describe()
# Out:
#               value
# count  16373.000000
# mean    3544.474458
# std     3253.663708
# min        0.000000
# 25%     1818.800000
# 50%     2282.000000
# 75%     5700.000000
# max    15441.000000

# %%
apple_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17399 entries, 0 to 17398
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user        17399 non-null  object
#  1   type        17399 non-null  object
#  2   startDate   17399 non-null  object
#  3   endDate     17399 non-null  object
#  4   value       16373 non-null  float64
#  5   unit        14893 non-null  object
#  6   sourceName  13144 non-null  object
#  7   device      11590 non-null  object
#  8   metadata    12962 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 1.2+ MB

# %%
apple_health.shape
# Out:
# (17399, 9)

# %% [markdown]
# ### Fitbit Daily Activity
# - missing Id values
# - multiple activity intentsity columns
# - calories inconsistent
# - sedentaryMinutes stable?
# - provides the richest activity breakdown but still requires completeness checks.

# %%
fitbit_daily_activity = pd.read_csv("wearables_synthetic_raw/fitbit_dailyActivity_2024.csv")

# %%
fitbit_daily_activity.head()
# Out:
#                Id ActivityDate  TotalSteps  TrackerDistance  \
# 0  U_5NQ4FMYZYCWT  01-Jan-2024     10233.0             7.31
# 1  U_5NQ4FMYZYCWT   2024-01-02      7380.0             5.27
# 2  U_5NQ4FMYZYCWT  03-Jan-2024     11229.0             8.02
# 3  U_5NQ4FMYZYCWT   2024-01-04      6515.0             4.65
# 4  U_5NQ4FMYZYCWT   01/05/2024     10808.0             7.72
#
#    VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 0                NaN                 22.0                  38.0
# 1               26.0                 24.0                  33.0
# 2               77.0                 31.0                  73.0
# 3               19.0                 38.0                 104.0
# 4               58.0                 38.0                  40.0
#
#    SedentaryMinutes  Calories  source
# 0            1225.0    2617.0  Fitbit
# 1               NaN    1841.0  Fitbit
# 2            1234.0    2107.0  Fitbit
# 3            1306.0    2216.0  Fitbit
# 4               NaN    2367.0  Fitbit

# %%
fitbit_daily_activity.describe()
# Out:
#          TotalSteps  TrackerDistance  VeryActiveMinutes  FairlyActiveMinutes  \
# count  15095.000000     14329.000000       13722.000000         13768.000000
# mean    6798.779000         4.845919          39.390759            19.920250
# std     2575.168771         1.844863          23.887781            11.832044
# min        0.000000         0.000000           0.000000             0.000000
# 25%     5075.000000         3.610000          22.000000            10.000000
# 50%     6771.000000         4.830000          39.000000            20.000000
# 75%     8523.500000         6.070000          56.000000            30.000000
# max    15982.000000        11.420000         128.000000            40.000000
#
#        LightlyActiveMinutes  SedentaryMinutes      Calories
# count          13701.000000      13978.000000  14809.000000
# mean             110.406175       1293.857777   2163.292120
# std               63.446038         57.365587    278.818776
# min                0.000000       1137.000000   1200.000000
# 25%               55.000000       1248.000000   1975.000000
# 50%              111.000000       1294.000000   2163.000000
# 75%              165.000000       1340.000000   2349.000000
# max              220.000000       1439.000000   3233.000000

# %%
fitbit_daily_activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15595 entries, 0 to 15594
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    14299 non-null  object
#  1   ActivityDate          15595 non-null  object
#  2   TotalSteps            15095 non-null  float64
#  3   TrackerDistance       14329 non-null  float64
#  4   VeryActiveMinutes     13722 non-null  float64
#  5   FairlyActiveMinutes   13768 non-null  float64
#  6   LightlyActiveMinutes  13701 non-null  float64
#  7   SedentaryMinutes      13978 non-null  float64
#  8   Calories              14809 non-null  float64
#  9   source                15595 non-null  object
# dtypes: float64(7), object(3)
# memory usage: 1.2+ MB

# %%
fitbit_daily_activity.shape
# Out:
# (15595, 10)

# %% [markdown]
# ### Fitbit Resting HR
# - timezones sometimes missing
# - rhr_confidence is categorical
# - one value per user per day mostly
# - cleaner physiological signals

# %%
fitbit_resting_HR = pd.read_csv("wearables_synthetic_raw/fitbit_restingHR_2024.csv")

# %%
fitbit_resting_HR.head()
# Out:
#                id                   dateTime  restingHeartRate    timezone  \
# 0  U_5NQ4FMYZYCWT           2024/01/01 00:00              66.3         NaN
# 1  U_5NQ4FMYZYCWT  2024-01-02 00:00:00 +0400              68.0  Asia/Tokyo
# 2  U_5NQ4FMYZYCWT           2024/01/03 00:00              65.3  Asia/Tokyo
# 3  U_5NQ4FMYZYCWT           2024/01/04 00:00              67.9  Asia/Tokyo
# 4  U_5NQ4FMYZYCWT           2024/01/05 00:00              68.6         NaN
#
#      device rhr_confidence
# 0  Charge 5            low
# 1       NaN           high
# 2   Sense 2            NaN
# 3  Charge 5            low
# 4   Sense 2            low

# %%
fitbit_resting_HR.describe()
# Out:
#        restingHeartRate
# count      14380.000000
# mean          70.387636
# std           13.122674
# min           45.000000
# 25%           61.200000
# 50%           70.000000
# 75%           79.900000
# max           95.000000

# %%
fitbit_resting_HR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15595 entries, 0 to 15594
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                15595 non-null  object
#  1   dateTime          15595 non-null  object
#  2   restingHeartRate  14380 non-null  float64
#  3   timezone          14069 non-null  object
#  4   device            11767 non-null  object
#  5   rhr_confidence    13355 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 731.1+ KB

# %%
fitbit_resting_HR.shape
# Out:
# (15595, 6)

# %% [markdown]
# ### Fitbit Sleep
# - multiple rows per night
# - isMainSleep is boolean and integer
# - sleep segments cross midnight
# - some segments missing minutesAsleep

# %%
fitbit_sleep = pd.read_csv("wearables_synthetic_raw/fitbit_sleep_2024.csv")

# %%
fitbit_sleep.head()
# Out:
#                id          sleep_start            sleep_end  minutesAsleep  \
# 0  U_5NQ4FMYZYCWT     2024/01/01 20:51  2024-01-01 23:44:00          173.0
# 1  U_5NQ4FMYZYCWT  2024-01-01 22:25:00  2024-01-02 01:20:00            NaN
# 2  U_5NQ4FMYZYCWT  2024-01-02 22:17:00  2024-01-03 04:17:00          360.0
# 3  U_5NQ4FMYZYCWT  2024-01-03 23:24:00  2024-01-04 05:24:00          360.0
# 4  U_5NQ4FMYZYCWT  2024-01-04 22:51:00  2024-01-05 01:43:00          172.0
#
#    minutesAwake  sleep_efficiency isMainSleep
# 0          22.0              79.0        TRUE
# 1          50.0              83.0       FALSE
# 2          12.0              91.0           0
# 3          56.0              79.0       FALSE
# 4          42.0              82.0           0

# %%
fitbit_sleep.describe()
# Out:
#        minutesAsleep  minutesAwake  sleep_efficiency
# count   23535.000000  21418.000000      22275.000000
# mean      220.472148     34.854655         84.396543
# std        93.618440     19.216191          6.856900
# min        40.000000      0.000000         58.000000
# 25%       145.000000     21.000000         80.000000
# 50%       192.000000     34.000000         84.000000
# 75%       339.000000     48.000000         89.000000
# max       360.000000    114.000000         98.000000

# %%
fitbit_sleep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25264 entries, 0 to 25263
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                25264 non-null  object
#  1   sleep_start       25264 non-null  object
#  2   sleep_end         25264 non-null  object
#  3   minutesAsleep     23535 non-null  float64
#  4   minutesAwake      21418 non-null  float64
#  5   sleep_efficiency  22275 non-null  float64
#  6   isMainSleep       21542 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 1.3+ MB

# %%
fitbit_sleep.shape
# Out:
# (25264, 7)

# %% [markdown]
# ### Oura
# - Sleep durations are in seconds
# - multiple date formats
# - missing deep/REM sleep
# - Readiness present even though sleep components missing sometimes
# - temperature deviation is subtle
# - sleep first, not activity

# %%
oura_sleep = pd.read_csv("wearables_synthetic_raw/oura_sleep.csv")

# %%
oura_sleep.head()
# Out:
#            UserId              date  total_sleep_duration  \
# 0  U_XAJI0Y6DPBHS  2024/01/01 00:00               29828.0
# 1  U_XAJI0Y6DPBHS       02-Jan-2024               29699.0
# 2  U_XAJI0Y6DPBHS       03-Jan-2024               28117.0
# 3  U_XAJI0Y6DPBHS  2024/01/04 00:00               27670.0
# 4  U_XAJI0Y6DPBHS       05-Jan-2024               24997.0
#
#    deep_sleep_duration  rem_sleep_duration  restless  readiness_score  \
# 0               8774.0              5059.0      32.0             61.0
# 1               6517.0              7863.0      36.0             54.0
# 2                  NaN              3761.0      19.0             61.0
# 3               5275.0              3884.0       NaN             68.0
# 4               5604.0              5465.0      14.0             61.0
#
#    temperature_deviation        bedtime_start          bedtime_end source
# 0                   0.15  2024-01-01T23:59:00  2024-01-02T05:56:00   Oura
# 1                  -0.14  2024-01-02T20:45:00  2024-01-03T05:24:00   Oura
# 2                   0.31  2024-01-04T00:03:00  2024-01-04T05:33:00   Oura
# 3                   0.23  2024-01-04T20:33:00  2024-01-05T07:25:00   Oura
# 4                   0.10  2024-01-05T23:43:00  2024-01-06T06:29:00   Oura

# %%
oura_sleep.describe()
# Out:
#        total_sleep_duration  deep_sleep_duration  rem_sleep_duration  \
# count          10048.000000          9668.000000         9633.000000
# mean           26367.856986          5023.108295         5772.095609
# std             3947.149387          1763.910395         2017.579749
# min            12659.000000             0.000000            0.000000
# 25%            23593.750000          3793.000000         4387.000000
# 50%            26397.000000          4947.500000         5649.000000
# 75%            29221.250000          6176.000000         7031.000000
# max            38115.000000         12992.000000        14360.000000
#
#           restless  readiness_score  temperature_deviation
# count  8943.000000      9864.000000            9263.000000
# mean     27.533266        66.260341               0.024750
# std      13.659394        10.810618               0.181057
# min       0.000000        25.000000              -0.580000
# 25%      18.000000        59.000000              -0.100000
# 50%      27.000000        66.000000               0.020000
# 75%      37.000000        74.000000               0.150000
# max      80.000000       100.000000               0.710000

# %%
oura_sleep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10945 entries, 0 to 10944
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   UserId                 10945 non-null  object
#  1   date                   10945 non-null  object
#  2   total_sleep_duration   10048 non-null  float64
#  3   deep_sleep_duration    9668 non-null   float64
#  4   rem_sleep_duration     9633 non-null   float64
#  5   restless               8943 non-null   float64
#  6   readiness_score        9864 non-null   float64
#  7   temperature_deviation  9263 non-null   float64
#  8   bedtime_start          10945 non-null  object
#  9   bedtime_end            10945 non-null  object
#  10  source                 10945 non-null  object
# dtypes: float64(6), object(5)
# memory usage: 940.7+ KB

# %%
oura_sleep.shape
# Out:
# (10945, 11)

# %% [markdown]
# ### Samsung
# - steps has negative values ??
# - uid sometimes missing
# - mixed date formats
# - tz is inconsistent
# - sleep is in hours

# %%
samsung = pd.read_csv("wearables_synthetic_raw/samsung_health_daily.csv")

# %%
samsung.head()
# Out:
#               uid              date    steps  calories_burned  sleep_duration  \
# 0  U_W2PCN9T84AZY  2024/01/01 00:00  10014.0           2236.0             NaN
# 1  U_W2PCN9T84AZY        01/02/2024      NaN           2160.0            7.23
# 2  U_W2PCN9T84AZY  2024/01/03 00:00   7295.0           2111.0            5.02
# 3             NaN        01/04/2024   6942.0           2503.0            6.43
# 4  U_W2PCN9T84AZY  2024/01/05 00:00   7975.0           2017.0            7.14
#
#     rhr workout_type  workout_min            tz
# 0   NaN          Gym         52.0           NaN
# 1  62.3         none         56.0  Asia/Karachi
# 2  64.8         yoga         42.0        +04:00
# 3  70.9         yoga         57.0           UTC
# 4  70.0         none         53.0        +04:00

# %%
samsung.describe()
# Out:
#               steps  calories_burned  sleep_duration           rhr  \
# count  14561.000000     14108.000000    13648.000000  13647.000000
# mean    6921.889843      2170.980862        7.038381     71.211255
# std     2350.326282       295.745559        1.028254     15.094710
# min     -431.000000      1001.000000        3.500000     41.100000
# 25%     5385.000000      1972.000000        6.300000     59.200000
# 50%     7062.000000      2175.000000        7.030000     69.600000
# 75%     8586.000000      2370.000000        7.750000     84.000000
# max    14511.000000      3281.000000       10.500000     99.300000
#
#         workout_min
# count  12485.000000
# mean      38.095795
# std       22.676615
# min        0.000000
# 25%       21.000000
# 50%       38.000000
# 75%       54.000000
# max      127.000000

# %%
samsung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15155 entries, 0 to 15154
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   uid              14387 non-null  object
#  1   date             15155 non-null  object
#  2   steps            14561 non-null  float64
#  3   calories_burned  14108 non-null  float64
#  4   sleep_duration   13648 non-null  float64
#  5   rhr              13647 non-null  float64
#  6   workout_type     10909 non-null  object
#  7   workout_min      12485 non-null  float64
#  8   tz               11338 non-null  object
# dtypes: float64(5), object(4)
# memory usage: 1.0+ MB

# %%
samsung.shape
# Out:
# (15155, 9)

# %% [markdown]
# ### Whoop
# - member_id =! user_id format
# - recovery missing more than strain
# - whoop = physiology + recovery model
# - does not fully align with fitbit/samsung like oura

# %%
whoop_cycles = pd.read_csv("wearables_synthetic_raw/whoop_cycles.csv")

# %%
whoop_cycles.head()
# Out:
#       member_id                 cycle_date  strain  recovery_score  hrv_rmssd  \
# 0  JZA7TZ0YNCXL  2024-01-01 00:00:00 -0800    9.04            73.0       60.0
# 1  JZA7TZ0YNCXL                 2024-01-02    8.41             NaN       66.0
# 2  JZA7TZ0YNCXL                 2024-01-03    7.81            70.0       58.0
# 3  JZA7TZ0YNCXL        2024-01-04T00:00:00    3.30            61.0       51.0
# 4  JZA7TZ0YNCXL                 2024-01-05    6.94            58.0       79.0
#
#    sleep_performance      notes
# 0               76.0        NaN
# 1               88.0        NaN
# 2               64.0        NaN
# 3               84.0  late meal
# 4               79.0        NaN

# %%
whoop_cycles.describe()
# Out:
#             strain  recovery_score    hrv_rmssd  sleep_performance
# count  9889.000000     9759.000000  9598.000000        9365.000000
# mean      9.241093       58.982785    51.696812          69.915643
# std       4.484720       12.779257    16.526605          11.790204
# min       0.000000       16.000000    15.000000          29.000000
# 25%       6.030000       50.000000    40.000000          62.000000
# 50%       9.220000       59.000000    51.000000          70.000000
# 75%      12.390000       67.000000    63.000000          78.000000
# max      21.000000       99.000000   120.000000         100.000000

# %%
whoop_cycles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10620 entries, 0 to 10619
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   member_id          10620 non-null  object
#  1   cycle_date         10620 non-null  object
#  2   strain             9889 non-null   float64
#  3   recovery_score     9759 non-null   float64
#  4   hrv_rmssd          9598 non-null   float64
#  5   sleep_performance  9365 non-null   float64
#  6   notes              7101 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 580.9+ KB

# %%
whoop_cycles.shape
# Out:
# (10620, 7)

# %% [markdown]
# ### Grain Definitions
#
# - users: 1 row = 1 user (static user attributes)
# - devices_registry: 1 row = 1 user–device (device ownership metadata)
#
# - apple_health: 1 row = 1 measurement event (event-level, heterogeneous metrics)
#
# - fitbit_daily_activity: 1 row = 1 user–day (daily activity summary)
# - fitbit_sleep: 1 row = 1 sleep segment (multiple rows per night)
# - fitbit_resting_HR: 1 row = 1 user–day (daily resting heart rate summary)
#
# - samsung_health_daily: 1 row = 1 user–day (daily summary; messy dates/units/invalid values)
#
# - whoop_cycles: 1 row = 1 user–day (strain/recovery-focused daily cycle)
# - oura_sleep: 1 row = 1 user–day (sleep-first daily summary)

# %% [markdown]
# ## Initial Canonical Table Design
# 1. Primary Key:
#  - (user_id, date)
# 2. Table Density:
#  - Sparse table
# 3. Metrics:
#  - Required:
#    - user_id
#    - date
#  - Optional:
#    - steps
#    - sleep_hours
#    - resting_hr
#    - calories_burned
#    - strain
#    - readiness
#  - Derived:
#    - rolling averages
#    - consistency metrics
#    - volatility measures
